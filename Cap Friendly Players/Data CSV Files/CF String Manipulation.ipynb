# %% [markdown]
# This file, once complete, will obtain a dataframe that contains every trade that occured during the 2019-20 NHL season. I am going to scrape the CapFriendly Website using beautiful soup and selenium and then use pandas to get it into the dataframe.

# %%
import pandas as pd
import lxml

# %% [markdown]
# Now that necessary packages are installed, I need to read the csv's in for each season as dataframes, and then fix each PLAYER column so that it just reads the player name, and not "1.PLAYER NAME".

# %%
df= pd.read_csv("Cap Friendly 2016-17 Player Data.csv")
df.head(5)
# Out:
#    Unnamed: 0             PLAYER TEAM AGE  DATE OF BIRTH        COUNTRY  \
# 0           0  1. Jonathan Toews  NaN  28  Apr. 29, 1988         Canada
# 1           1    2. Patrick Kane  DET  27  Nov. 19, 1988  United States
# 2           2    3. Anze Kopitar  LAK  28  Aug. 24, 1987       Slovenia
# 3           3   4. Alex Ovechkin  WSH  30  Sep. 17, 1985         Russia
# 4           4   5. Evgeni Malkin  PIT  29  Jul. 31, 1986         Russia
#
#              WEIGHT          HEIGHT POS HANDED  ... EXPIRY  EXP. YEAR  \
# 0   201 lbs - 91 kg   6'2" - 188 cm   C   Left  ...    UFA       2023
# 1   177 lbs - 80 kg  5'10" - 178 cm  RW   Left  ...    UFA       2023
# 2  225 lbs - 102 kg   6'3" - 191 cm   C   Left  ...    UFA       2024
# 3  236 lbs - 107 kg   6'3" - 191 cm  LW  Right  ...    UFA       2021
# 4   195 lbs - 88 kg   6'3" - 191 cm   C   Left  ...    UFA       2022
#
#        CAP HIT CAP HIT %          AAV       SALARY  BASE SALARY       MINORS  \
# ...

# %% [markdown]
# Alright so I can see that everthing I need got extracted into the dataframe which is awesome. All the information I need can get successfully pulled. However, the format is an absolute disaster. I need to filter what information is going into the df and how it is getting pulled. Just going to send to a csv file real quick to view it better.

# %% [markdown]
# Alright from looking at it, A ton of information gets repeated (Lot of repeat variables). SO, I just need to filter and then use some text splitting to get information where it needs to go in the dataframe. I am going to attempt to drop the repetive columns of the dataframe in the next code chunk. Since I am dropping all but two columns, I am simply going to make a new dataframe that contains two columns.

# %%
#df['PLAYER'] = df['PLAYER'].str.split('.', n=1).str[1].str.strip()
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0            PLAYER TEAM AGE  DATE OF BIRTH        COUNTRY  \
# 0           0    Jonathan Toews  NaN  28  Apr. 29, 1988         Canada
# 1           1      Patrick Kane  DET  27  Nov. 19, 1988  United States
# 2           2      Anze Kopitar  LAK  28  Aug. 24, 1987       Slovenia
# 3           3     Alex Ovechkin  WSH  30  Sep. 17, 1985         Russia
# 4           4     Evgeni Malkin  PIT  29  Jul. 31, 1986         Russia
# 5           5       P.K. Subban  NaN  27   May 13, 1989         Canada
# 6           6     Sidney Crosby  PIT  28   Aug. 7, 1987         Canada
# 7           7       Corey Perry  EDM  31   May 16, 1985         Canada
# 8           8    Steven Stamkos  TBL  26   Feb. 7, 1990         Canada
# 9           9  Henrik Lundqvist  NaN  34   Mar. 2, 1982         Sweden
#
#              WEIGHT          HEIGHT    POS HANDED  ... EXPIRY  EXP. YEAR  \
# 0   201 lbs - 91 kg   6'2" - 188 cm      C   Left  ...    UFA       2023
# ...

# %%
df.to_csv('CF 2016-17 Active Players Data.csv')

# %% [markdown]
# Season 2017-18

# %%
df= pd.read_csv("Cap Friendly 2017-18 Player Data.csv")
df.head(5)

# %%
#df['PLAYER'] = df['PLAYER'].str.split('.', n=1).str[1].str.strip()
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)

# %%
df.to_csv('CF 2017-18 Active Players Data.csv')

# %% [markdown]
# Season 2018-19

# %%
df= pd.read_csv("Cap Friendly 2018-19 Player Data.csv")
#df.head(5)

# %%
#df['PLAYER'] = df['PLAYER'].str.split('.', n=1).str[1].str.strip()
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)

# %%
df.to_csv('CF 2018-19 Active Players Data.csv')

# %% [markdown]
# Season 2019-20

# %%
df= pd.read_csv("Cap Friendly 2019-20 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)

# %%
df.to_csv('CF 2019-20 Active Players Data.csv')

# %% [markdown]
# Season 2020-21

# %%
df= pd.read_csv("Cap Friendly 2020-21 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0            PLAYER TEAM  AGE  DATE OF BIRTH        COUNTRY  \
# 0           0    Connor McDavid  EDM   23  Jan. 13, 1997         Canada
# 1           1    Artemi Panarin  NYR   28  Oct. 30, 1991         Russia
# 2           2   Auston Matthews  TOR   22  Sep. 17, 1997  United States
# 3           3     Erik Karlsson  PIT   30   May 31, 1990         Sweden
# 4           4      Drew Doughty  LAK   30   Dec. 8, 1989         Canada
# 5           5      John Tavares  TOR   29  Sep. 20, 1990         Canada
# 6           6   Mitchell Marner  TOR   23    May 5, 1997         Canada
# 7           7       Carey Price  MTL   32  Aug. 16, 1987         Canada
# 8           8      Patrick Kane  DET   31  Nov. 19, 1988  United States
# 9           9  Sergei Bobrovsky  FLA   31  Sep. 20, 1988         Russia
#
#             WEIGHT          HEIGHT    POS HANDED  ... EXPIRY  EXP. YEAR  \
# 0  193 lbs - 88 kg   6'1" - 185 cm      C   Left  ...    UFA       2026
# ...

# %%
df.to_csv('CF 2020-21 Active Players Data.csv')

# %% [markdown]
# Season 2021-22

# %%
df= pd.read_csv("Cap Friendly 2021-22 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0           PLAYER TEAM  AGE  DATE OF BIRTH        COUNTRY  \
# 0           0   Connor McDavid  EDM   24  Jan. 13, 1997         Canada
# 1           1   Artemi Panarin  NYR   29  Oct. 30, 1991         Russia
# 2           2  Auston Matthews  TOR   23  Sep. 17, 1997  United States
# 3           3    Erik Karlsson  PIT   31   May 31, 1990         Sweden
# 4           4     Drew Doughty  LAK   31   Dec. 8, 1989         Canada
# 5           5     John Tavares  TOR   30  Sep. 20, 1990         Canada
# 6           6  Mitchell Marner  TOR   24    May 5, 1997         Canada
# 7           7      Carey Price  MTL   33  Aug. 16, 1987         Canada
# 8           8   Jonathan Toews  NaN   33  Apr. 29, 1988         Canada
# 9           9     Patrick Kane  DET   32  Nov. 19, 1988  United States
#
#             WEIGHT          HEIGHT    POS HANDED  ... EXPIRY  EXP. YEAR  \
# 0  193 lbs - 88 kg   6'1" - 185 cm      C   Left  ...    UFA       2026
# ...

# %%
df.to_csv('CF 2021-22 Active Players Data.csv')

# %% [markdown]
# Season 2022-23

# %%
df= pd.read_csv("Cap Friendly 2022-23 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0             PLAYER TEAM  AGE  DATE OF BIRTH        COUNTRY  \
# 0           0     Connor McDavid  EDM   25  Jan. 13, 1997         Canada
# 1           1     Artemi Panarin  NYR   30  Oct. 30, 1991         Russia
# 2           2    Auston Matthews  TOR   24  Sep. 17, 1997  United States
# 3           3      Erik Karlsson  PIT   32   May 31, 1990         Sweden
# 4           4       Drew Doughty  LAK   32   Dec. 8, 1989         Canada
# 5           5       John Tavares  TOR   31  Sep. 20, 1990         Canada
# 6           6    Mitchell Marner  TOR   25    May 5, 1997         Canada
# 7           7     Jonathan Toews  NaN   34  Apr. 29, 1988         Canada
# 8           8       Patrick Kane  DET   33  Nov. 19, 1988  United States
# 9           9  Aleksander Barkov  FLA   26   Sep. 2, 1995        Finland
#
#             WEIGHT          HEIGHT    POS HANDED  ... EXPIRY  EXP. YEAR  \
# 0  193 lbs - 88 kg   6'1" - 185 cm      C   Left  ...    UFA       2026
# ...

# %%
df.to_csv('CF 2022-23 Active Players Data.csv')

# %% [markdown]
# Season 2023-24

# %%
df= pd.read_csv("Cap Friendly 2023-24 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0              PLAYER TEAM  AGE  DATE OF BIRTH         COUNTRY  \
# 0           0    Nathan MacKinnon  COL   27   Sep. 1, 1995          Canada
# 1           1      Connor McDavid  EDM   26  Jan. 13, 1997          Canada
# 2           2      Artemi Panarin  NYR   31  Oct. 30, 1991          Russia
# 3           3     Auston Matthews  TOR   25  Sep. 17, 1997   United States
# 4           4       Erik Karlsson  PIT   33   May 31, 1990          Sweden
# 5           5      David Pastrnak  BOS   27   May 25, 1996  Czech Republic
# 6           6        John Tavares  TOR   32  Sep. 20, 1990          Canada
# 7           7        Drew Doughty  LAK   33   Dec. 8, 1989          Canada
# 8           8     Mitchell Marner  TOR   26    May 5, 1997          Canada
# 9           9  Jonathan Huberdeau  CGY   30   Jun. 4, 1993          Canada
#
#             WEIGHT          HEIGHT     POS HANDED  ... EXPIRY  EXP. YEAR  \
# ...

# %%
df.to_csv('CF 2023-24 Active Players Data.csv')

# %% [markdown]
# Season 2024-25

# %%
df= pd.read_csv("Cap Friendly 2024-25 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0            PLAYER TEAM  AGE  DATE OF BIRTH         COUNTRY  \
# 0           0   Auston Matthews  TOR   26  Sep. 17, 1997   United States
# 1           1  Nathan MacKinnon  COL   28   Sep. 1, 1995          Canada
# 2           2    Connor McDavid  EDM   27  Jan. 13, 1997          Canada
# 3           3    Artemi Panarin  NYR   32  Oct. 30, 1991          Russia
# 4           4  William Nylander  TOR   28    May 1, 1996          Canada
# 5           5     Erik Karlsson  PIT   34   May 31, 1990          Sweden
# 6           6    David Pastrnak  BOS   28   May 25, 1996  Czech Republic
# 7           7      Drew Doughty  LAK   34   Dec. 8, 1989          Canada
# 8           8      John Tavares  TOR   33  Sep. 20, 1990          Canada
# 9           9   Mitchell Marner  TOR   27    May 5, 1997          Canada
#
#             WEIGHT          HEIGHT    POS HANDED  ... EXPIRY  EXP. YEAR  \
# 0  215 lbs - 98 kg   6'3" - 191 cm      C   Left  ...    UFA       2028
# ...

# %%
df.to_csv('CF 2024-25 Active Players Data.csv')

# %% [markdown]
# Season 2025-26

# %%
df= pd.read_csv("Cap Friendly 2025-26 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0              PLAYER TEAM  AGE  DATE OF BIRTH         COUNTRY  \
# 0           0     Auston Matthews  TOR   27  Sep. 17, 1997   United States
# 1           1    Nathan MacKinnon  COL   29   Sep. 1, 1995          Canada
# 2           2      Connor McDavid  EDM   28  Jan. 13, 1997          Canada
# 3           3      Artemi Panarin  NYR   33  Oct. 30, 1991          Russia
# 4           4       Erik Karlsson  PIT   35   May 31, 1990          Sweden
# 5           5    William Nylander  TOR   29    May 1, 1996          Canada
# 6           6      David Pastrnak  BOS   29   May 25, 1996  Czech Republic
# 7           7        Drew Doughty  LAK   35   Dec. 8, 1989          Canada
# 8           8  Jonathan Huberdeau  CGY   32   Jun. 4, 1993          Canada
# 9           9         Carey Price  MTL   37  Aug. 16, 1987          Canada
#
#             WEIGHT          HEIGHT     POS HANDED  ... EXPIRY  EXP. YEAR  \
# ...

# %%
df.to_csv('CF 2025-26 Active Players Data.csv')

# %% [markdown]
# Season 2026-27

# %%
df= pd.read_csv("Cap Friendly 2026-27 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0              PLAYER TEAM  AGE  DATE OF BIRTH         COUNTRY  \
# 0           0     Auston Matthews  TOR   28  Sep. 17, 1997   United States
# 1           1    Nathan MacKinnon  COL   30   Sep. 1, 1995          Canada
# 2           2       Erik Karlsson  PIT   36   May 31, 1990          Sweden
# 3           3    William Nylander  TOR   30    May 1, 1996          Canada
# 4           4      David Pastrnak  BOS   30   May 25, 1996  Czech Republic
# 5           5        Drew Doughty  LAK   36   Dec. 8, 1989          Canada
# 6           6  Jonathan Huberdeau  CGY   33   Jun. 4, 1993          Canada
# 7           7   Aleksander Barkov  FLA   30   Sep. 2, 1995         Finland
# 8           8        Tyler Seguin  DAL   34  Jan. 31, 1992          Canada
# 9           9       Sebastian Aho  CAR   28  Jul. 26, 1997         Finland
#
#             WEIGHT         HEIGHT     POS HANDED  ... EXPIRY  EXP. YEAR  \
# ...

# %%
df.to_csv('CF 2026-27 Active Players Data.csv')

# %% [markdown]
# Season 2027-28

# %%
df= pd.read_csv("Cap Friendly 2027-28 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0              PLAYER TEAM  AGE  DATE OF BIRTH         COUNTRY  \
# 0           0     Auston Matthews  TOR   29  Sep. 17, 1997   United States
# 1           1    Nathan MacKinnon  COL   31   Sep. 1, 1995          Canada
# 2           2    William Nylander  TOR   31    May 1, 1996          Canada
# 3           3      David Pastrnak  BOS   31   May 25, 1996  Czech Republic
# 4           4  Jonathan Huberdeau  CGY   34   Jun. 4, 1993          Canada
# 5           5   Aleksander Barkov  FLA   31   Sep. 2, 1995         Finland
# 6           6       Sebastian Aho  CAR   29  Jul. 26, 1997         Finland
# 7           7     Johnny Gaudreau  CBJ   33  Aug. 13, 1993   United States
# 8           8    Zachary Werenski  CBJ   29  Jul. 19, 1997   United States
# 9           9  Andrei Vasilevskiy  TBL   32  Jul. 25, 1994          Russia
#
#             WEIGHT         HEIGHT     POS HANDED  ... EXPIRY  EXP. YEAR  \
# ...

# %%
df.to_csv('CF 2027-28 Active Players Data.csv')

# %% [markdown]
# Season 2028-29

# %%
df= pd.read_csv("Cap Friendly 2028-29 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0              PLAYER TEAM  AGE  DATE OF BIRTH         COUNTRY  \
# 0           0    Nathan MacKinnon  COL   32   Sep. 1, 1995          Canada
# 1           1    William Nylander  TOR   32    May 1, 1996          Canada
# 2           2      David Pastrnak  BOS   32   May 25, 1996  Czech Republic
# 3           3  Jonathan Huberdeau  CGY   35   Jun. 4, 1993          Canada
# 4           4   Aleksander Barkov  FLA   32   Sep. 2, 1995         Finland
# 5           5       Sebastian Aho  CAR   30  Jul. 26, 1997         Finland
# 6           6     Johnny Gaudreau  CBJ   34  Aug. 13, 1993   United States
# 7           7          Seth Jones  CHI   33   Oct. 3, 1994   United States
# 8           8       Brayden Point  TBL   32  Mar. 13, 1996          Canada
# 9           9     Matthew Tkachuk  FLA   30  Dec. 11, 1997   United States
#
#             WEIGHT          HEIGHT     POS HANDED  ... EXPIRY  EXP. YEAR  \
# ...

# %%
df.to_csv('CF 2028-29 Active Players Data.csv')

# %% [markdown]
# Season 2029-30

# %%
df= pd.read_csv("Cap Friendly 2029-30 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0              PLAYER TEAM  AGE  DATE OF BIRTH         COUNTRY  \
# 0           0    Nathan MacKinnon  COL   33   Sep. 1, 1995          Canada
# 1           1    William Nylander  TOR   33    May 1, 1996          Canada
# 2           2      David Pastrnak  BOS   33   May 25, 1996  Czech Republic
# 3           3  Jonathan Huberdeau  CGY   36   Jun. 4, 1993          Canada
# 4           4   Aleksander Barkov  FLA   33   Sep. 2, 1995         Finland
# 5           5       Sebastian Aho  CAR   31  Jul. 26, 1997         Finland
# 6           6          Seth Jones  CHI   34   Oct. 3, 1994   United States
# 7           7       Brayden Point  TBL   33  Mar. 13, 1996          Canada
# 8           8     Matthew Tkachuk  FLA   31  Dec. 11, 1997   United States
# 9           9       Darnell Nurse  EDM   34   Feb. 4, 1995          Canada
#
#              WEIGHT          HEIGHT     POS HANDED  ... EXPIRY  EXP. YEAR  \
# ...

# %%
df.to_csv('CF 2029-30 Active Players Data.csv')

# %% [markdown]
# Season 2030-31

# %%
df= pd.read_csv("Cap Friendly 2030-31 Player Data.csv")

# %%
df['PLAYER'] = df['PLAYER'].str.replace(r'^\d+\.\s*', '', regex=True)
df.head(10)
# Out:
#    Unnamed: 0              PLAYER TEAM  AGE  DATE OF BIRTH         COUNTRY  \
# 0           0    Nathan MacKinnon  COL   34   Sep. 1, 1995          Canada
# 1           1    William Nylander  TOR   34    May 1, 1996          Canada
# 2           2      David Pastrnak  BOS   34   May 25, 1996  Czech Republic
# 3           3  Jonathan Huberdeau  CGY   37   Jun. 4, 1993          Canada
# 4           4       Sebastian Aho  CAR   32  Jul. 26, 1997         Finland
# 5           5       Jake Guentzel  TBL   35   Oct. 6, 1994   United States
# 6           6          Timo Meier  NJD   33   Oct. 8, 1996     Switzerland
# 7           7        Dylan Larkin  DET   33  Jul. 30, 1996   United States
# 8           8        Sam Reinhart  FLA   34   Nov. 6, 1995          Canada
# 9           9      Mark Scheifele  WPG   37  Mar. 15, 1993          Canada
#
#             WEIGHT          HEIGHT     POS HANDED  ... EXPIRY  EXP. YEAR  \
# ...

# %%
df.to_csv('CF 2030-31 Active Players Data.csv')
